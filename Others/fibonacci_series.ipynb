# %%
# fibonacci series - brute force

def F(n):
    print('Computing F('+str(n)+')')
    if n <= 1:
        return n
    else:
        return F(n - 1) + F(n - 2)

print('F(6) = ',F(10))
# Out:
# Computing F(10)
# Computing F(9)
# Computing F(8)
# Computing F(7)
# Computing F(6)
# Computing F(5)
# Computing F(4)
# Computing F(3)
# Computing F(2)
# Computing F(1)
# Computing F(0)
# Computing F(1)
# Computing F(2)
# Computing F(1)
# Computing F(0)
# Computing F(3)
# Computing F(2)
# Computing F(1)
# Computing F(0)
# Computing F(1)
# Computing F(4)
# Computing F(3)
# Computing F(2)
# Computing F(1)
# Computing F(0)
# Computing F(1)
# Computing F(2)
# Computing F(1)
# Computing F(0)
# Computing F(5)
# Computing F(4)
# Computing F(3)
# Computing F(2)
# Computing F(1)
# Computing F(0)
# Computing F(1)
# Computing F(2)
# Computing F(1)
# Computing F(0)
# Computing F(3)
# Computing F(2)
# Computing F(1)
# Computing F(0)
# Computing F(1)
# Computing F(6)
# Computing F(5)
# Computing F(4)
# Computing F(3)
# Computing F(2)
# Computing F(1)
# Computing F(0)
# Computing F(1)
# Computing F(2)
# Computing F(1)
# Computing F(0)
# Computing F(3)
# Computing F(2)
# Computing F(1)
# ...
