# %%
# get the shortest/smallest subsequence of a string
def subsequence(string,size,output,index=-1,curr="",max=0):
    if index == size:
        return
    
    if len(curr) > 0:
        output.append(curr)
        
    i = index + 1
    while i < size:
        curr += string[i]
        subsequence(string,size,output,i,curr,max)
        curr = curr[0:-1]
        i += 1     
        
def get_min_subsequences(strings):
    min = float('inf')
    output.sort(key=lambda x: len(x), reverse=True)
    for i in output:
        if len(i) < min:
            min_subsequences = []
            min = len(i)
            min_subsequences.append((i,len(i)))
        elif len(i) == min and min != 0:
            min_subsequences.append((i,len(i)))
    return min_subsequences
        
string = "geeks" 
output = []
subsequence(string,len(string),output)
print(output)
min_subsequences = get_min_subsequences(output)
print(min_subsequences)
# Out:
# ['g', 'ge', 'gee', 'geek', 'geeks', 'gees', 'gek', 'geks', 'ges', 'ge', 'gek', 'geks', 'ges', 'gk', 'gks', 'gs', 'e', 'ee', 'eek', 'eeks', 'ees', 'ek', 'eks', 'es', 'e', 'ek', 'eks', 'es', 'k', 'ks', 's']
# [('g', 1), ('e', 1), ('e', 1), ('k', 1), ('s', 1)]
