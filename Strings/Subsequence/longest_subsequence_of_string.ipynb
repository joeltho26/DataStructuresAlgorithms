# %%
# get the largest/longest subsequence of a string
def subsequence(string,size,output,index=-1,curr="",max=0):
    if index == size:
        return
    
    if len(curr) > 0:
        output.append(curr)
        
    i = index + 1
    while i < size:
        curr += string[i]
        subsequence(string,size,output,i,curr,max)
        curr = curr[0:-1]
        i += 1     
        
def get_max_subsequences(strings):
    max = 0
    output.sort(key=lambda x: len(x), reverse=True)
    for i in output:
        if len(i) > max:
            max_subsequences = []
            max = len(i)
            max_subsequences.append((i,len(i)))
        elif len(i) == max and max != 0:
            max_subsequences.append((i,len(i)))
    return max_subsequences
        
string = "geeks" 
output = []
subsequence(string,len(string),output)
print(output)
max_subsequences = get_max_subsequences(output)
print(max_subsequences)
# Out:
# ['g', 'ge', 'gee', 'geek', 'geeks', 'gees', 'gek', 'geks', 'ges', 'ge', 'gek', 'geks', 'ges', 'gk', 'gks', 'gs', 'e', 'ee', 'eek', 'eeks', 'ees', 'ek', 'eks', 'es', 'e', 'ek', 'eks', 'es', 'k', 'ks', 's']
# [('geeks', 5)]
