# %%
# find all anagrams in a string and return matched indexes

def findAnagrams(s, p):
    k = len(p)
    size = len(s) - k + 1
    count = 0
    anagrams = []
    for i in range(size):
        val = s[i:i+k]
        for j in range(len(p)):
            if p[j] in val:
                index = val.index(p[j])
                val = val[:index] + val[index+1:] 
                if val == "":
                    anagrams.append(i)  
            else:
                break
    return anagrams
            
s = "cbaebabacd"
p = "abc" 
print(findAnagrams(s,p))

s = "abab"
p = "ab"
print(findAnagrams(s,p))
  
s = "..."
p = "..."  
print(findAnagrams(s,p))
# Out:
# [0, 6]
# [0, 1, 2]
# [0, 10001]
