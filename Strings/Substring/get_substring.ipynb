# %%
# get substring from a string based on position and length of characters

def get_substring(string,pos,length):
    limit = len(string) - pos
    if length < limit:
        return string[pos:pos+length]
    else:
        return "substring length exceeds the overall string length"

if __name__ == "__main__":
    a = "abcbaabcaababcad"
    print(get_substring(a,5,10))
# Out:
# abcaababca
