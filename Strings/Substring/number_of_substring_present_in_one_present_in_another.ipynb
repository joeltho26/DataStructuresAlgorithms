# %%
# number of times the substring of a string is the same as the other string

def count_substring(S1,S2):
    substrings = []
    count = 0
    for i in range(len(S2)):
        for j in range(i+1,len(S2)+1):
            if S1 == S2[i:j]:
                count +=1
    return count

S2 = "abcbaabcaababcad"
S1 = "aab"
print(count_substring(S1,S2))

S1 = "ab"
print(count_substring(S1,S2))

S1 = "abcd"
print(count_substring(S1,S2))
# Out:
# 2
# 4
# 0
